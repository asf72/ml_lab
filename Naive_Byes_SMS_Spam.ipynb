# %% [markdown]
# <a href="https://colab.research.google.com/github/asf72/ml_lab/blob/main/Naive_Byes_SMS_Spam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_table('/content/SMSSpamCollection', header=None, names=['label', 'message'])
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df ['label'] = df.label.map({'ham' : 0, 'spam':1})
df.head()
# Out:
#    label                                            message  label_encoded
# 0      0  Go until jurong point, crazy.. Available only ...              0
# 1      0                      Ok lar... Joking wif u oni...              0
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...              1
# 3      0  U dun say so early hor... U c already then say...              0
# 4      0  Nah I don't think he goes to usf, he lives aro...              0
